# %% [markdown]
# ## Import Packages

# %%
import os
import sys
import numpy as np
import pandas as pd
from time import time

from sklearn.model_selection import train_test_split
from scipy.io import loadmat

# %% [markdown]
# ## Import PyOD packages and methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Import Metrics Packages

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Define data file and read X and y

# %%
mat_file_list = ['E:/LetsUpgrade/Project Day 1/arrhythmia.mat',
                 'E:/LetsUpgrade/Project Day 1/cardio.mat',
                 'E:/LetsUpgrade/Project Day 1/glass.mat',
                 'E:/LetsUpgrade/Project Day 1/ionosphere.mat',
                 'E:/LetsUpgrade/Project Day 1/letter.mat',
                 'E:/LetsUpgrade/Project Day 1/lympho.mat',
                 'E:/LetsUpgrade/Project Day 1/mnist.mat',
                 'E:/LetsUpgrade/Project Day 1/musk.mat',
                 'E:/LetsUpgrade/Project Day 1/optdigits.mat',
                 'E:/LetsUpgrade/Project Day 1/pendigits.mat',
                 'E:/LetsUpgrade/Project Day 1/pima.mat',
                 'E:/LetsUpgrade/Project Day 1/satellite.mat',
                 'E:/LetsUpgrade/Project Day 1/satimage-2.mat',
                 'E:/LetsUpgrade/Project Day 1/shuttle.mat',
                 'E:/LetsUpgrade/Project Day 1/vertebral.mat',
                 'E:/LetsUpgrade/Project Day 1/vowels.mat',
                 'E:/LetsUpgrade/Project Day 1/wbc.mat']

# %% [markdown]
# ## Reading a mat file

# %%
data=loadmat('E:/LetsUpgrade/Project Day 1/cardio.mat')
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %% [markdown]
# ## Define 9 outlier detection tools to be compared

# %%
df_columns = ['Data','#Samples','# Dimensions','Outlier Perc','ABOD','CBLOF','FB','HBOS','IForest','KNN','LOF','MCD','OCSVM','PCA']

# %%
#Creating empty dataframes
roc_df=pd.DataFrame(columns=df_columns)  #region of characteristics Performance evolution table
prn_df=pd.DataFrame(columns=df_columns)  #precision_n_scores Performance evolution table
time_df=pd.DataFrame(columns=df_columns)

# %% [markdown]
# ## Exploring all mat files

# %%
for mat_file in mat_file_list:
    print("\n..Processing",mat_file,'...')
    mat=loadmat(os.path.join('E:/LetsUpgrade/Project Day 1',mat_file))
    
    X=mat['X']
    y=mat['y'].ravel()  #converting 2D to 1D so (that space is redcued)
    outliers_fraction=np.count_nonzero(y)/len(y)
    outliers_percentage=round(outliers_fraction*100,ndigits=4)
    
     #Construct containers for saving result
    roc_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]
    prn_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]
    time_list=[mat_file[:-4],X.shape[0],X.shape[1],outliers_percentage]

    #60% data for trainin g and 40% for testing
    random_state=np.random.RandomState(42)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=random_state)
    
    #Standardizing data for processing
    X_train_norm,X_test_norm=standardizer(X_train,X_test)
    classifiers={'Angle-based Outlier Detector (ABOD)' : ABOD(contamination=outliers_fraction),
                 'Cluster-based Local Outlier Factor' : CBLOF(contamination=outliers_fraction,check_estimator=False,random_state=random_state),
                 'Feature Bagging' : FeatureBagging(contamination=outliers_fraction,random_state=random_state),
                 'Histogram-base Outlier Detection (HBOS)' : HBOS(contamination=outliers_fraction),
                 'Isolation Forest' : IForest(contamination=outliers_fraction, random_state=random_state),
                 'K Nearest Neignors (KNN)' : KNN(contamination=outliers_fraction),
                 'Local Outlier Factor (LOF)' : LOF(contamination=outliers_fraction),
                 'Minimum Covariance Determinat (MCD)' : MCD(contamination=outliers_fraction, random_state=random_state),
                 'One-class SVM (OCSVM)' : OCSVM(contamination=outliers_fraction),
                 'Principal Component Ananlysis (PCA)' : PCA(contamination=outliers_fraction, random_state=random_state),
                }
    for clf_name, clf in classifiers.items():
        t0=time() #time before training
        clf.fit(X_train_norm)   #for each algorithm, the model is trained
        test_scores=clf.decision_function(X_test_norm) #testing model score
        t1=time() #time for testing or time when testing completed
        duration=round(t1-t0,ndigits=4) #time taken to complete training
        time_list.append(duration)
        roc=round(roc_auc_score(y_test,test_scores),ndigits=4)
        prn=round(precision_n_scores(y_test,test_scores),ndigits=4)
        print('{clf_name} ROC:{roc},precision @ rank n:{prn},' 'execution time : {duration}s'.format(clf_name=clf_name,roc=roc,prn=prn,duration=duration))
        roc_list.append(roc)
        prn_list.append(prn)
    
    temp_df=pd.DataFrame(time_list).transpose()
    temp_df.columns=df_columns
    time_df=pd.concat([time_df,temp_df],axis=0)

    temp_df=pd.DataFrame(roc_list).transpose()
    temp_df.columns=df_columns
    roc_df=pd.concat([roc_df,temp_df],axis=0)

    temp_df=pd.DataFrame(prn_list).transpose()
    temp_df.columns=df_columns
    prn_df=pd.concat([prn_df,temp_df],axis=0)
# Out:
# ..Processing E:/LetsUpgrade/Project Day 1/arrhythmia.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7687,precision @ rank n:0.3571,execution time : 0.1811s
# Cluster-based Local Outlier Factor ROC:0.7684,precision @ rank n:0.4643,execution time : 0.1318s
# Feature Bagging ROC:0.7799,precision @ rank n:0.5,execution time : 0.637s
# Histogram-base Outlier Detection (HBOS) ROC:0.8511,precision @ rank n:0.5714,execution time : 0.0855s
# Isolation Forest ROC:0.8527,precision @ rank n:0.5714,execution time : 0.4974s
# K Nearest Neignors (KNN) ROC:0.782,precision @ rank n:0.5,execution time : 0.0937s
# Local Outlier Factor (LOF) ROC:0.7787,precision @ rank n:0.4643,execution time : 0.0781s
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.8228,precision @ rank n:0.4286,execution time : 0.7248s
# One-class SVM (OCSVM) ROC:0.7986,precision @ rank n:0.5,execution time : 0.0312s
# Principal Component Ananlysis (PCA) ROC:0.7997,precision @ rank n:0.5,execution time : 0.0469s
#
# ..Processing E:/LetsUpgrade/Project Day 1/cardio.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5928,precision @ rank n:0.2838,execution time : 0.5108s
# Cluster-based Local Outlier Factor ROC:0.8547,precision @ rank n:0.5541,execution time : 0.1562s
# Feature Bagging ROC:0.6565,precision @ rank n:0.2297,execution time : 1.0094s
# Histogram-base Outlier Detection (HBOS) ROC:0.87,precision @ rank n:0.5135,execution time : 0.0s
# Isolation Forest ROC:0.9304,precision @ rank n:0.5405,execution time : 0.5032s
# K Nearest Neignors (KNN) ROC:0.7642,precision @ rank n:0.4054,execution time : 0.1809s
# Local Outlier Factor (LOF) ROC:0.6432,precision @ rank n:0.2162,execution time : 0.1139s
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.683054484776363 > -233.782932977363458). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.917349977189730 > -235.362429125008902). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.599361413842615 > -222.059282931323736). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-227.859567128077060 > -229.746480260986914). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-155.487715639168186 > -222.859022327153667). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.101358123166818 > -224.859189874234659). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-222.099940991427104 > -223.515854248805596). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-222.059183928710752 > -222.226316853413692). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.979383582323294 > -221.259763233710430). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-153.504254210185366 > -217.778615777774775). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-154.479023052950708 > -224.577877400519156). You may want to try with a higher value of support_fraction (current value: 0.510).
#   RuntimeWarning)
# Minimum Covariance Determinat (MCD) ROC:0.811,precision @ rank n:0.4865,execution time : 0.7077s
# One-class SVM (OCSVM) ROC:0.9462,precision @ rank n:0.527,execution time : 0.1149s
# Principal Component Ananlysis (PCA) ROC:0.9581,precision @ rank n:0.6216,execution time : 0.0s
#
# ..Processing E:/LetsUpgrade/Project Day 1/glass.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7805,precision @ rank n:0.25,execution time : 0.0469s
# Cluster-based Local Outlier Factor ROC:0.9024,precision @ rank n:0.25,execution time : 0.1404s
# Feature Bagging ROC:0.8293,precision @ rank n:0.25,execution time : 0.1072s
# Histogram-base Outlier Detection (HBOS) ROC:0.7256,precision @ rank n:0.25,execution time : 0.008s
# Isolation Forest ROC:0.7287,precision @ rank n:0.25,execution time : 0.6406s
# K Nearest Neignors (KNN) ROC:0.8902,precision @ rank n:0.25,execution time : 0.016s
# Local Outlier Factor (LOF) ROC:0.7287,precision @ rank n:0.25,execution time : 0.008s
# Minimum Covariance Determinat (MCD) ROC:0.7957,precision @ rank n:0.0,execution time : 0.0728s
# One-class SVM (OCSVM) ROC:0.753,precision @ rank n:0.25,execution time : 0.0s
# Principal Component Ananlysis (PCA) ROC:0.747,precision @ rank n:0.25,execution time : 0.0s
#
# ..Processing E:/LetsUpgrade/Project Day 1/ionosphere.mat ...
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.744624141124874 > -93.552983490404344). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.456973809953059 > -93.264867512175542). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.537884733666839 > -93.303896447144169). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.456973809953059 > -93.290201669515966). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.382381110533391 > -93.186741282438433). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-29.464647391380186 > -93.198137100014492). You may want to try with a higher value of support_fraction (current value: 0.539).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.9247,precision @ rank n:0.8868,execution time : 0.1559s
# Cluster-based Local Outlier Factor ROC:0.8999,precision @ rank n:0.7925,execution time : 0.0998s
# Feature Bagging ROC:0.9286,precision @ rank n:0.7736,execution time : 0.1127s
# Histogram-base Outlier Detection (HBOS) ROC:0.5154,precision @ rank n:0.3585,execution time : 0.016s
# Isolation Forest ROC:0.8433,precision @ rank n:0.6604,execution time : 0.593s
# K Nearest Neignors (KNN) ROC:0.9226,precision @ rank n:0.8868,execution time : 0.0156s
# Local Outlier Factor (LOF) ROC:0.9312,precision @ rank n:0.7736,execution time : 0.0s
# Minimum Covariance Determinat (MCD) ROC:0.9657,precision @ rank n:0.8868,execution time : 0.125s
# One-class SVM (OCSVM) ROC:0.8799,precision @ rank n:0.7736,execution time : 0.0s
# Principal Component Ananlysis (PCA) ROC:0.8068,precision @ rank n:0.6226,execution time : 0.0156s
#
# ..Processing E:/LetsUpgrade/Project Day 1/letter.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8949,precision @ rank n:0.3721,execution time : 0.5671s
# Cluster-based Local Outlier Factor ROC:0.7612,precision @ rank n:0.186,execution time : 0.1719s
# Feature Bagging ROC:0.8663,precision @ rank n:0.3721,execution time : 0.9953s
# Histogram-base Outlier Detection (HBOS) ROC:0.6248,precision @ rank n:0.093,execution time : 0.0156s
# Isolation Forest ROC:0.6403,precision @ rank n:0.093,execution time : 0.7178s
# K Nearest Neignors (KNN) ROC:0.8689,precision @ rank n:0.3488,execution time : 0.1875s
# Local Outlier Factor (LOF) ROC:0.8781,precision @ rank n:0.3721,execution time : 0.1232s
# Minimum Covariance Determinat (MCD) ROC:0.8119,precision @ rank n:0.186,execution time : 1.8417s
# One-class SVM (OCSVM) ROC:0.5827,precision @ rank n:0.1395,execution time : 0.1406s
# Principal Component Ananlysis (PCA) ROC:0.5142,precision @ rank n:0.1163,execution time : 0.0s
#
# ..Processing E:/LetsUpgrade/Project Day 1/lympho.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9138,precision @ rank n:0.0,execution time : 0.0859s
# Cluster-based Local Outlier Factor ROC:1.0,precision @ rank n:1.0,execution time : 0.0854s
# Feature Bagging ROC:1.0,precision @ rank n:1.0,execution time : 0.0625s
# Histogram-base Outlier Detection (HBOS) ROC:1.0,precision @ rank n:1.0,execution time : 0.0s
# Isolation Forest ROC:1.0,precision @ rank n:1.0,execution time : 0.4455s
# K Nearest Neignors (KNN) ROC:0.9828,precision @ rank n:0.5,execution time : 0.0s
# Local Outlier Factor (LOF) ROC:1.0,precision @ rank n:1.0,execution time : 0.0156s
# Minimum Covariance Determinat (MCD) ROC:0.8966,precision @ rank n:0.5,execution time : 0.0469s
# One-class SVM (OCSVM) ROC:1.0,precision @ rank n:1.0,execution time : 0.0156s
# Principal Component Ananlysis (PCA) ROC:1.0,precision @ rank n:1.0,execution time : 0.0s
#
# ..Processing E:/LetsUpgrade/Project Day 1/mnist.mat ...
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-225.145894607378892 > -299.797683112086986). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.7682,precision @ rank n:0.3643,execution time : 8.3704s
# Cluster-based Local Outlier Factor ROC:0.8339,precision @ rank n:0.3941,execution time : 1.7816s
# Feature Bagging ROC:0.6936,precision @ rank n:0.3234,execution time : 53.2317s
# Histogram-base Outlier Detection (HBOS) ROC:0.5578,precision @ rank n:0.0967,execution time : 0.0625s
# Isolation Forest ROC:0.8045,precision @ rank n:0.2714,execution time : 2.5819s
# K Nearest Neignors (KNN) ROC:0.8423,precision @ rank n:0.4349,execution time : 7.6343s
# Local Outlier Factor (LOF) ROC:0.7012,precision @ rank n:0.3309,execution time : 7.6104s
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.8553,precision @ rank n:0.2268,execution time : 4.2366s
# One-class SVM (OCSVM) ROC:0.8622,precision @ rank n:0.4015,execution time : 4.938s
# Principal Component Ananlysis (PCA) ROC:0.8613,precision @ rank n:0.3903,execution time : 0.1875s
#
# ..Processing E:/LetsUpgrade/Project Day 1/musk.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.1012,precision @ rank n:0.0294,execution time : 2.6001s
# Cluster-based Local Outlier Factor ROC:1.0,precision @ rank n:1.0,execution time : 0.465s
# Feature Bagging ROC:0.5705,precision @ rank n:0.1471,execution time : 14.2617s
# Histogram-base Outlier Detection (HBOS) ROC:1.0,precision @ rank n:1.0,execution time : 0.0781s
# Isolation Forest ROC:1.0,precision @ rank n:0.9706,execution time : 1.6095s
# K Nearest Neignors (KNN) ROC:0.7729,precision @ rank n:0.2059,execution time : 1.9476s
# Local Outlier Factor (LOF) ROC:0.5567,precision @ rank n:0.1471,execution time : 1.7916s
# Minimum Covariance Determinat (MCD) ROC:1.0,precision @ rank n:1.0,execution time : 14.6163s
# One-class SVM (OCSVM) ROC:1.0,precision @ rank n:1.0,execution time : 1.1688s
# Principal Component Ananlysis (PCA) ROC:1.0,precision @ rank n:1.0,execution time : 0.218s
#
# ..Processing E:/LetsUpgrade/Project Day 1/optdigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.4601,precision @ rank n:0.0,execution time : 3.2994s
# Cluster-based Local Outlier Factor ROC:0.7515,precision @ rank n:0.0,execution time : 0.5576s
# Feature Bagging ROC:0.4197,precision @ rank n:0.0164,execution time : 13.8039s
# Histogram-base Outlier Detection (HBOS) ROC:0.8962,precision @ rank n:0.1803,execution time : 0.04s
# Isolation Forest ROC:0.6531,precision @ rank n:0.0164,execution time : 1.241s
# K Nearest Neignors (KNN) ROC:0.3717,precision @ rank n:0.0,execution time : 2.1082s
# Local Outlier Factor (LOF) ROC:0.4191,precision @ rank n:0.0164,execution time : 1.762s
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinat (MCD) ROC:0.4226,precision @ rank n:0.0,execution time : 1.713s
# One-class SVM (OCSVM) ROC:0.4817,precision @ rank n:0.0,execution time : 1.5114s
# Principal Component Ananlysis (PCA) ROC:0.507,precision @ rank n:0.0,execution time : 0.0625s
#
# ..Processing E:/LetsUpgrade/Project Day 1/pendigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.677,precision @ rank n:0.0725,execution time : 2.147s
# Cluster-based Local Outlier Factor ROC:0.8488,precision @ rank n:0.2029,execution time : 0.3474s
# Feature Bagging ROC:0.4674,precision @ rank n:0.0725,execution time : 3.8395s
# Histogram-base Outlier Detection (HBOS) ROC:0.9261,precision @ rank n:0.2609,execution time : 0.0156s
# Isolation Forest ROC:0.9555,precision @ rank n:0.3768,execution time : 0.8169s
# K Nearest Neignors (KNN) ROC:0.7603,precision @ rank n:0.1594,execution time : 0.7465s
# Local Outlier Factor (LOF) ROC:0.4578,precision @ rank n:0.0725,execution time : 0.7181s
# Minimum Covariance Determinat (MCD) ROC:0.8387,precision @ rank n:0.1159,execution time : 2.3954s
# One-class SVM (OCSVM) ROC:0.946,precision @ rank n:0.3333,execution time : 1.0941s
# Principal Component Ananlysis (PCA) ROC:0.9402,precision @ rank n:0.3478,execution time : 0.0156s
#
# ..Processing E:/LetsUpgrade/Project Day 1/pima.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.665,precision @ rank n:0.4314,execution time : 0.221s
# Cluster-based Local Outlier Factor ROC:0.6724,precision @ rank n:0.4608,execution time : 0.089s
# Feature Bagging ROC:0.6551,precision @ rank n:0.4608,execution time : 0.1378s
# Histogram-base Outlier Detection (HBOS) ROC:0.7029,precision @ rank n:0.5392,execution time : 0.008s
# Isolation Forest ROC:0.6843,precision @ rank n:0.4608,execution time : 0.4366s
# K Nearest Neignors (KNN) ROC:0.7123,precision @ rank n:0.5,execution time : 0.0312s
# Local Outlier Factor (LOF) ROC:0.6621,precision @ rank n:0.4706,execution time : 0.0s
# Minimum Covariance Determinat (MCD) ROC:0.6942,precision @ rank n:0.4706,execution time : 0.0781s
# One-class SVM (OCSVM) ROC:0.6423,precision @ rank n:0.4412,execution time : 0.0156s
# Principal Component Ananlysis (PCA) ROC:0.6444,precision @ rank n:0.451,execution time : 0.0156s
#
# ..Processing E:/LetsUpgrade/Project Day 1/satellite.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5598,precision @ rank n:0.3723,execution time : 2.4774s
# Cluster-based Local Outlier Factor ROC:0.7117,precision @ rank n:0.5321,execution time : 0.4972s
# Feature Bagging ROC:0.5331,precision @ rank n:0.3597,execution time : 8.1289s
# Histogram-base Outlier Detection (HBOS) ROC:0.7574,precision @ rank n:0.5585,execution time : 0.0156s
# Isolation Forest ROC:0.7113,precision @ rank n:0.5497,execution time : 1.1058s
# K Nearest Neignors (KNN) ROC:0.6755,precision @ rank n:0.4818,execution time : 1.2939s
# Local Outlier Factor (LOF) ROC:0.5339,precision @ rank n:0.3572,execution time : 1.1523s
# Minimum Covariance Determinat (MCD) ROC:0.7863,precision @ rank n:0.6692,execution time : 3.0708s
# One-class SVM (OCSVM) ROC:0.6437,precision @ rank n:0.5119,execution time : 1.4288s
# Principal Component Ananlysis (PCA) ROC:0.5762,precision @ rank n:0.4642,execution time : 0.0312s
#
# ..Processing E:/LetsUpgrade/Project Day 1/satimage-2.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8675,precision @ rank n:0.3333,execution time : 2.096s
# Cluster-based Local Outlier Factor ROC:0.9998,precision @ rank n:0.9259,execution time : 0.3879s
# Feature Bagging ROC:0.573,precision @ rank n:0.1111,execution time : 6.789s
# Histogram-base Outlier Detection (HBOS) ROC:0.9809,precision @ rank n:0.6667,execution time : 0.0156s
# Isolation Forest ROC:0.9951,precision @ rank n:0.8148,execution time : 0.9251s
# K Nearest Neignors (KNN) ROC:0.9595,precision @ rank n:0.4444,execution time : 1.1179s
# Local Outlier Factor (LOF) ROC:0.5699,precision @ rank n:0.1111,execution time : 0.9727s
# Minimum Covariance Determinat (MCD) ROC:0.9964,precision @ rank n:0.6296,execution time : 2.9918s
# One-class SVM (OCSVM) ROC:0.9997,precision @ rank n:0.8889,execution time : 1.2596s
# Principal Component Ananlysis (PCA) ROC:0.9834,precision @ rank n:0.8148,execution time : 0.032s
#
# ..Processing E:/LetsUpgrade/Project Day 1/shuttle.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6096,precision @ rank n:0.1853,execution time : 17.8753s
# Cluster-based Local Outlier Factor ROC:0.602,precision @ rank n:0.2189,execution time : 1.1078s
# Feature Bagging ROC:0.4735,precision @ rank n:0.0701,execution time : 75.0102s
# Histogram-base Outlier Detection (HBOS) ROC:0.9842,precision @ rank n:0.9896,execution time : 0.0221s
# Isolation Forest ROC:0.9973,precision @ rank n:0.9571,execution time : 3.9887s
# K Nearest Neignors (KNN) ROC:0.643,precision @ rank n:0.2153,execution time : 9.1657s
# Local Outlier Factor (LOF) ROC:0.529,precision @ rank n:0.1323,execution time : 12.287s
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.015419314992862 > -77.703198913328549). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.056909975554191 > -77.324765861735116). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.506791553473228 > -80.045464139191353). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.943212765343688 > -76.629734979619514). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.452643627402345 > -77.716844960427366). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.571698750426734 > -77.399032302546900). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.522976523651359 > -79.146767532045359). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.707105184494701 > -75.878642585482211). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.719571273942634 > -79.982421213381315). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.591734819743706 > -78.118471170975155). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.868351361592985 > -75.457808493890838). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.070472587660696 > -77.681288841356164). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.750203866498552 > -78.874758353322534). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.026801085015336 > -75.343716916844798). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.252079764007846 > -81.102698967535289). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.326044326567072 > -78.436701304842558). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.046284772693568 > -75.804162283688299). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.766392078685477 > -75.921449582815768). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.669886346304068 > -75.965763743684249). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.445945615387387 > -76.830768800359266). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.714206729042672 > -76.794548375532173). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.990263161088734 > -76.723776741553465). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.953780527540744 > -78.048056725825759). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.716198702885350 > -77.110709462845179). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.638097464380571 > -78.147934726653432). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.931896538580553 > -76.194028921274551). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.939991729478855 > -79.537540146705282). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.964637824590369 > -76.683283077123662). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.184446302729427 > -77.408457350693141). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.681310207060633 > -77.540552060931390). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.288149560556171 > -77.089268317194183). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.273358323629012 > -78.876800366788316). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.228574063754145 > -79.876796846434175). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.993842880553196 > -77.782658839185999). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.023652254712545 > -77.779382230862367). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.783830710780101 > -77.287585929459510). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determinat (MCD) ROC:0.9901,precision @ rank n:0.7332,execution time : 12.5548s
# One-class SVM (OCSVM) ROC:0.9922,precision @ rank n:0.9578,execution time : 56.4797s
# Principal Component Ananlysis (PCA) ROC:0.9904,precision @ rank n:0.9542,execution time : 0.059s
#
# ..Processing E:/LetsUpgrade/Project Day 1/vertebral.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.3968,precision @ rank n:0.0909,execution time : 0.072s
# Cluster-based Local Outlier Factor ROC:0.3882,precision @ rank n:0.0,execution time : 0.067s
# Feature Bagging ROC:0.4289,precision @ rank n:0.0909,execution time : 0.042s
# Histogram-base Outlier Detection (HBOS) ROC:0.3166,precision @ rank n:0.0,execution time : 0.002s
# Isolation Forest ROC:0.3444,precision @ rank n:0.0,execution time : 0.3918s
# K Nearest Neignors (KNN) ROC:0.384,precision @ rank n:0.0,execution time : 0.02s
# Local Outlier Factor (LOF) ROC:0.4342,precision @ rank n:0.0909,execution time : 0.006s
# Minimum Covariance Determinat (MCD) ROC:0.4214,precision @ rank n:0.0,execution time : 0.065s
# One-class SVM (OCSVM) ROC:0.3947,precision @ rank n:0.0909,execution time : 0.002s
# Principal Component Ananlysis (PCA) ROC:0.3615,precision @ rank n:0.0,execution time : 0.003s
#
# ..Processing E:/LetsUpgrade/Project Day 1/vowels.mat ...
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.125078286203880 > -42.193997637653659). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.203296655673416 > -40.407112650254476). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-22.994244185500083 > -40.603416206306314). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-23.349846719521246 > -42.402611498304871). You may want to try with a higher value of support_fraction (current value: 0.528).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.9515,precision @ rank n:0.5,execution time : 0.4148s
# Cluster-based Local Outlier Factor ROC:0.9419,precision @ rank n:0.2727,execution time : 0.1119s
# Feature Bagging ROC:0.943,precision @ rank n:0.2273,execution time : 0.3128s
# Histogram-base Outlier Detection (HBOS) ROC:0.6365,precision @ rank n:0.0,execution time : 0.005s
# Isolation Forest ROC:0.7601,precision @ rank n:0.1364,execution time : 0.4987s
# K Nearest Neignors (KNN) ROC:0.9763,precision @ rank n:0.4545,execution time : 0.0979s
# Local Outlier Factor (LOF) ROC:0.9119,precision @ rank n:0.2727,execution time : 0.047s
# Minimum Covariance Determinat (MCD) ROC:0.6877,precision @ rank n:0.0455,execution time : 1.0204s
# One-class SVM (OCSVM) ROC:0.7763,precision @ rank n:0.1364,execution time : 0.051s
# Principal Component Ananlysis (PCA) ROC:0.5675,precision @ rank n:0.0909,execution time : 0.003s
#
# ..Processing E:/LetsUpgrade/Project Day 1/wbc.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9181,precision @ rank n:0.5455,execution time : 0.1019s
# Cluster-based Local Outlier Factor ROC:0.9259,precision @ rank n:0.5455,execution time : 0.086s
# Feature Bagging ROC:0.9555,precision @ rank n:0.7273,execution time : 0.098s
# Histogram-base Outlier Detection (HBOS) ROC:0.9594,precision @ rank n:0.6364,execution time : 0.01s
# Isolation Forest ROC:0.9355,precision @ rank n:0.6364,execution time : 0.3822s
# K Nearest Neignors (KNN) ROC:0.9426,precision @ rank n:0.7273,execution time : 0.024s
# Local Outlier Factor (LOF) ROC:0.9536,precision @ rank n:0.6364,execution time : 0.012s
# Minimum Covariance Determinat (MCD) ROC:0.9233,precision @ rank n:0.5455,execution time : 0.0949s
# One-class SVM (OCSVM) ROC:0.9433,precision @ rank n:0.6364,execution time : 0.005s
# Principal Component Ananlysis (PCA) ROC:0.9329,precision @ rank n:0.6364,execution time : 0.004s

# %%
roc_df
# Out:
#                                       Data #Samples # Dimensions Outlier Perc  \
# 0  E:/LetsUpgrade/Project Day 1/arrhythmia      452          274      14.6018
# 0      E:/LetsUpgrade/Project Day 1/cardio     1831           21       9.6122
# 0       E:/LetsUpgrade/Project Day 1/glass      214            9       4.2056
# 0  E:/LetsUpgrade/Project Day 1/ionosphere      351           33      35.8974
# 0      E:/LetsUpgrade/Project Day 1/letter     1600           32         6.25
# 0      E:/LetsUpgrade/Project Day 1/lympho      148           18       4.0541
# 0       E:/LetsUpgrade/Project Day 1/mnist     7603          100       9.2069
# 0        E:/LetsUpgrade/Project Day 1/musk     3062          166       3.1679
# 0   E:/LetsUpgrade/Project Day 1/optdigits     5216           64       2.8758
# 0   E:/LetsUpgrade/Project Day 1/pendigits     6870           16       2.2707
# 0        E:/LetsUpgrade/Project Day 1/pima      768            8      34.8958
# 0   E:/LetsUpgrade/Project Day 1/satellite     6435           36      31.6395
# 0  E:/LetsUpgrade/Project Day 1/satimage-2     5803           36       1.2235
# 0     E:/LetsUpgrade/Project Day 1/shuttle    49097            9       7.1511
# 0   E:/LetsUpgrade/Project Day 1/vertebral      240            6         12.5
# 0      E:/LetsUpgrade/Project Day 1/vowels     1456           12       3.4341
# 0         E:/LetsUpgrade/Project Day 1/wbc      378           30       5.5556
#
#      ABOD   CBLOF      FB    HBOS IForest     KNN     LOF     MCD   OCSVM  \
# 0  0.7687  0.7684  0.7799  0.8511  0.8527   0.782  0.7787  0.8228  0.7986
# 0  0.5928  0.8547  0.6565    0.87  0.9304  0.7642  0.6432   0.811  0.9462
# 0  0.7805  0.9024  0.8293  0.7256  0.7287  0.8902  0.7287  0.7957   0.753
# 0  0.9247  0.8999  0.9286  0.5154  0.8433  0.9226  0.9312  0.9657  0.8799
# 0  0.8949  0.7612  0.8663  0.6248  0.6403  0.8689  0.8781  0.8119  0.5827
# 0  0.9138       1       1       1       1  0.9828       1  0.8966       1
# 0  0.7682  0.8339  0.6936  0.5578  0.8045  0.8423  0.7012  0.8553  0.8622
# 0  0.1012       1  0.5705       1       1  0.7729  0.5567       1       1
# 0  0.4601  0.7515  0.4197  0.8962  0.6531  0.3717  0.4191  0.4226  0.4817
# 0   0.677  0.8488  0.4674  0.9261  0.9555  0.7603  0.4578  0.8387   0.946
# 0   0.665  0.6724  0.6551  0.7029  0.6843  0.7123  0.6621  0.6942  0.6423
# 0  0.5598  0.7117  0.5331  0.7574  0.7113  0.6755  0.5339  0.7863  0.6437
# 0  0.8675  0.9998   0.573  0.9809  0.9951  0.9595  0.5699  0.9964  0.9997
# 0  0.6096   0.602  0.4735  0.9842  0.9973   0.643   0.529  0.9901  0.9922
# 0  0.3968  0.3882  0.4289  0.3166  0.3444   0.384  0.4342  0.4214  0.3947
# 0  0.9515  0.9419   0.943  0.6365  0.7601  0.9763  0.9119  0.6877  0.7763
# 0  0.9181  0.9259  0.9555  0.9594  0.9355  0.9426  0.9536  0.9233  0.9433
#
#       PCA
# 0  0.7997
# 0  0.9581
# 0   0.747
# 0  0.8068
# 0  0.5142
# 0       1
# 0  0.8613
# 0       1
# 0   0.507
# 0  0.9402
# 0  0.6444
# 0  0.5762
# 0  0.9834
# 0  0.9904
# 0  0.3615
# 0  0.5675
# 0  0.9329

# %%
time_df
# Out:
#                                       Data #Samples # Dimensions Outlier Perc  \
# 0         E:/LetsUpgrade/Project Day 1/wbc      378           30       5.5556
# 0  E:/LetsUpgrade/Project Day 1/arrhythmia      452          274      14.6018
# 0      E:/LetsUpgrade/Project Day 1/cardio     1831           21       9.6122
# 0       E:/LetsUpgrade/Project Day 1/glass      214            9       4.2056
# 0  E:/LetsUpgrade/Project Day 1/ionosphere      351           33      35.8974
# 0      E:/LetsUpgrade/Project Day 1/letter     1600           32         6.25
# 0      E:/LetsUpgrade/Project Day 1/lympho      148           18       4.0541
# 0       E:/LetsUpgrade/Project Day 1/mnist     7603          100       9.2069
# 0        E:/LetsUpgrade/Project Day 1/musk     3062          166       3.1679
# 0   E:/LetsUpgrade/Project Day 1/optdigits     5216           64       2.8758
# 0   E:/LetsUpgrade/Project Day 1/pendigits     6870           16       2.2707
# 0        E:/LetsUpgrade/Project Day 1/pima      768            8      34.8958
# 0   E:/LetsUpgrade/Project Day 1/satellite     6435           36      31.6395
# 0  E:/LetsUpgrade/Project Day 1/satimage-2     5803           36       1.2235
# 0     E:/LetsUpgrade/Project Day 1/shuttle    49097            9       7.1511
# 0   E:/LetsUpgrade/Project Day 1/vertebral      240            6         12.5
# 0      E:/LetsUpgrade/Project Day 1/vowels     1456           12       3.4341
# 0         E:/LetsUpgrade/Project Day 1/wbc      378           30       5.5556
#
#       ABOD   CBLOF       FB    HBOS IForest     KNN     LOF      MCD    OCSVM  \
# 0   0.5455  0.5455   0.7273  0.6364  0.6364  0.7273  0.6364   0.5455   0.6364
# 0   0.1811  0.1318    0.637  0.0855  0.4974  0.0937  0.0781   0.7248   0.0312
# 0   0.5108  0.1562   1.0094       0  0.5032  0.1809  0.1139   0.7077   0.1149
# 0   0.0469  0.1404   0.1072   0.008  0.6406   0.016   0.008   0.0728        0
# 0   0.1559  0.0998   0.1127   0.016   0.593  0.0156       0    0.125        0
# 0   0.5671  0.1719   0.9953  0.0156  0.7178  0.1875  0.1232   1.8417   0.1406
# 0   0.0859  0.0854   0.0625       0  0.4455       0  0.0156   0.0469   0.0156
# 0   8.3704  1.7816  53.2317  0.0625  2.5819  7.6343  7.6104   4.2366    4.938
# 0   2.6001   0.465  14.2617  0.0781  1.6095  1.9476  1.7916  14.6163   1.1688
# 0   3.2994  0.5576  13.8039    0.04   1.241  2.1082   1.762    1.713   1.5114
# 0    2.147  0.3474   3.8395  0.0156  0.8169  0.7465  0.7181   2.3954   1.0941
# 0    0.221   0.089   0.1378   0.008  0.4366  0.0312       0   0.0781   0.0156
# 0   2.4774  0.4972   8.1289  0.0156  1.1058  1.2939  1.1523   3.0708   1.4288
# 0    2.096  0.3879    6.789  0.0156  0.9251  1.1179  0.9727   2.9918   1.2596
# 0  17.8753  1.1078  75.0102  0.0221  3.9887  9.1657  12.287  12.5548  56.4797
# 0    0.072   0.067    0.042   0.002  0.3918    0.02   0.006    0.065    0.002
# 0   0.4148  0.1119   0.3128   0.005  0.4987  0.0979   0.047   1.0204    0.051
# 0   0.1019   0.086    0.098    0.01  0.3822   0.024   0.012   0.0949    0.005
#
#       PCA
# 0  0.6364
# 0  0.0469
# 0       0
# 0       0
# 0  0.0156
# 0       0
# 0       0
# 0  0.1875
# 0   0.218
# 0  0.0625
# 0  0.0156
# 0  0.0156
# 0  0.0312
# 0   0.032
# 0   0.059
# 0   0.003
# 0   0.003
# 0   0.004

# %%
prn_df
# Out:
#                                       Data #Samples # Dimensions Outlier Perc  \
# 0  E:/LetsUpgrade/Project Day 1/arrhythmia      452          274      14.6018
# 0      E:/LetsUpgrade/Project Day 1/cardio     1831           21       9.6122
# 0       E:/LetsUpgrade/Project Day 1/glass      214            9       4.2056
# 0  E:/LetsUpgrade/Project Day 1/ionosphere      351           33      35.8974
# 0      E:/LetsUpgrade/Project Day 1/letter     1600           32         6.25
# 0      E:/LetsUpgrade/Project Day 1/lympho      148           18       4.0541
# 0       E:/LetsUpgrade/Project Day 1/mnist     7603          100       9.2069
# 0        E:/LetsUpgrade/Project Day 1/musk     3062          166       3.1679
# 0   E:/LetsUpgrade/Project Day 1/optdigits     5216           64       2.8758
# 0   E:/LetsUpgrade/Project Day 1/pendigits     6870           16       2.2707
# 0        E:/LetsUpgrade/Project Day 1/pima      768            8      34.8958
# 0   E:/LetsUpgrade/Project Day 1/satellite     6435           36      31.6395
# 0  E:/LetsUpgrade/Project Day 1/satimage-2     5803           36       1.2235
# 0     E:/LetsUpgrade/Project Day 1/shuttle    49097            9       7.1511
# 0   E:/LetsUpgrade/Project Day 1/vertebral      240            6         12.5
# 0      E:/LetsUpgrade/Project Day 1/vowels     1456           12       3.4341
# 0         E:/LetsUpgrade/Project Day 1/wbc      378           30       5.5556
#
#      ABOD   CBLOF      FB    HBOS IForest     KNN     LOF     MCD   OCSVM  \
# 0  0.3571  0.4643     0.5  0.5714  0.5714     0.5  0.4643  0.4286     0.5
# 0  0.2838  0.5541  0.2297  0.5135  0.5405  0.4054  0.2162  0.4865   0.527
# 0    0.25    0.25    0.25    0.25    0.25    0.25    0.25       0    0.25
# 0  0.8868  0.7925  0.7736  0.3585  0.6604  0.8868  0.7736  0.8868  0.7736
# 0  0.3721   0.186  0.3721   0.093   0.093  0.3488  0.3721   0.186  0.1395
# 0       0       1       1       1       1     0.5       1     0.5       1
# 0  0.3643  0.3941  0.3234  0.0967  0.2714  0.4349  0.3309  0.2268  0.4015
# 0  0.0294       1  0.1471       1  0.9706  0.2059  0.1471       1       1
# 0       0       0  0.0164  0.1803  0.0164       0  0.0164       0       0
# 0  0.0725  0.2029  0.0725  0.2609  0.3768  0.1594  0.0725  0.1159  0.3333
# 0  0.4314  0.4608  0.4608  0.5392  0.4608     0.5  0.4706  0.4706  0.4412
# 0  0.3723  0.5321  0.3597  0.5585  0.5497  0.4818  0.3572  0.6692  0.5119
# 0  0.3333  0.9259  0.1111  0.6667  0.8148  0.4444  0.1111  0.6296  0.8889
# 0  0.1853  0.2189  0.0701  0.9896  0.9571  0.2153  0.1323  0.7332  0.9578
# 0  0.0909       0  0.0909       0       0       0  0.0909       0  0.0909
# 0     0.5  0.2727  0.2273       0  0.1364  0.4545  0.2727  0.0455  0.1364
# 0  0.5455  0.5455  0.7273  0.6364  0.6364  0.7273  0.6364  0.5455  0.6364
#
#       PCA
# 0     0.5
# 0  0.6216
# 0    0.25
# 0  0.6226
# 0  0.1163
# 0       1
# 0  0.3903
# 0       1
# 0       0
# 0  0.3478
# 0   0.451
# 0  0.4642
# 0  0.8148
# 0  0.9542
# 0       0
# 0  0.0909
# 0  0.6364
